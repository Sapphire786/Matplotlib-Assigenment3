# %% [markdown]
# ## Assignment 3 Matplotlib
#
# **Instructions:** <br>
# a. write your answer after `# your answer here`. Do not delete any code that is in the cell, as the code facilitates checking your answers. If you happen to delete any code that prevents expected outputs, you may lose points. <br>
# b. make sure the plot shows all the information necessary, including but not limited to **title, axis labels with units, legend**, etc. <br>
# c. when you finish the assignment, make sure to use `Kernel` -> `Restart and Run All` to restart the kernel and rerun the entire notebook to generate the desired outputs, before submitting your assignment. <br>
# d. upload your .ipynb file. <br>
# <br>
# Each subquestion for Question 1 and 2 is worth 5 points (30 points in total), and each subquestion for Question 3 is worth 10 points (30 points in total). The total score for assignment 3 is 60 points.
#
# **Policy:** <br>
# Assignment submitted late will receive a late penalty (30% point reduction), regardless of the reason. Empty assignment or no submission receives 0 point.

# %% [markdown]
# ### Question 1
# Load the following dataset from seaborn and use functions in seaborn to draw plots.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pg = sns.load_dataset("penguins")
pg
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# 1.(1) Data exploration: remove NA rows and draw pair plots (pairwise variable plots). Use different colors to denote different species.

# %%
#your answer here
pg = pg.dropna()
sns.pairplot(pg, hue = "species")

# %% [markdown]
# 1.(2) Draw violin plot on bill length over species, using different colors for the species.

# %%
#your answer here
sns.violinplot(x ="species", y ="bill_length_mm", data = pg)
plt.show()

# %% [markdown]
# 1.(3) Draw a joint density plot (kernel density estimate) of bill length and bill depth.

# %%
#your answer here
sns.jointplot(data = pg, x = "bill_length_mm", y = "bill_depth_mm", kind = "kde")

# %% [markdown]
# 1.(4) Draw a regression plot of bill length over body mass, which shows a scatterplot, a fitted line, and two histograms for the two variables.

# %%
#your answer here
sns.jointplot(data = pg, x="bill_length_mm", y="body_mass_g", kind="reg")

# %% [markdown]
# ### Question 2
# Load a dataset from Seaborn and answer the following questions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
att = sns.load_dataset("attention")
att
# Out:
#     Unnamed: 0  subject attention  solutions  score
# 0            0        1   divided          1    2.0
# 1            1        2   divided          1    3.0
# 2            2        3   divided          1    3.0
# 3            3        4   divided          1    5.0
# 4            4        5   divided          1    4.0
# 5            5        6   divided          1    5.0
# 6            6        7   divided          1    5.0
# 7            7        8   divided          1    5.0
# 8            8        9   divided          1    2.0
# 9            9       10   divided          1    6.0
# 10          10       11   focused          1    6.0
# 11          11       12   focused          1    8.0
# 12          12       13   focused          1    6.0
# 13          13       14   focused          1    8.0
# 14          14       15   focused          1    8.0
# 15          15       16   focused          1    6.0
# 16          16       17   focused          1    7.0
# 17          17       18   focused          1    7.0
# 18          18       19   focused          1    5.0
# 19          19       20   focused          1    6.0
# 20          20        1   divided          2    4.0
# 21          21        2   divided          2    4.0
# 22          22        3   divided          2    5.0
# 23          23        4   divided          2    7.0
# 24          24        5   divided          2    5.0
# 25          25        6   divided          2    5.0
# 26          26        7   divided          2    4.5
# 27          27        8   divided          2    7.0
# 28          28        9   divided          2    3.0
# 29          29       10   divided          2    5.0
# 30          30       11   focused          2    5.0
# 31          31       12   focused          2    9.0
# 32          32       13   focused          2    5.0
# 33          33       14   focused          2    8.0
# 34          34       15   focused          2    8.0
# 35          35       16   focused          2    8.0
# 36          36       17   focused          2    7.0
# 37          37       18   focused          2    8.0
# 38          38       19   focused          2    6.0
# 39          39       20   focused          2    6.0
# 40          40        1   divided          3    7.0
# 41          41        2   divided          3    5.0
# 42          42        3   divided          3    6.0
# 43          43        4   divided          3    5.0
# 44          44        5   divided          3    8.0
# 45          45        6   divided          3    6.0
# 46          46        7   divided          3    6.0
# 47          47        8   divided          3    8.0
# 48          48        9   divided          3    7.0
# 49          49       10   divided          3    6.0
# 50          50       11   focused          3    6.0
# 51          51       12   focused          3    8.0
# 52          52       13   focused          3    9.0
# 53          53       14   focused          3    7.0
# 54          54       15   focused          3    7.0
# 55          55       16   focused          3    7.0
# 56          56       17   focused          3    6.0
# 57          57       18   focused          3    6.0
# 58          58       19   focused          3    6.0
# 59          59       20   focused          3    5.0

# %% [markdown]
# 2. (1) Draw a facet histogram, with two rows for the attention group and three columns for the solutions.

# %%
#your answer here
att = sns.FacetGrid(att, row ="attention", col="solutions", margin_titles = True)
att.map_dataframe(sns.histplot, x="score", bins=np.linspace(0,10,10))

# %% [markdown]
# 2. (2) Draw a factor boxplot of scores (y-axis) over attention group (x-axis). In each attention group, show the boxplot over the three solution groups (legend).

# %%
#your answer here
g = sns.catplot("attention", "score", 
                    "solutions", #legend group
                    data=att, kind="box")
g.set_axis_labels("attention", "score");
plt.title('Boxplot of Scores over Attention Group')
# Out:
# /Users/farihaahmed/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Boxplot of Scores over Attention Group')

# %% [markdown]
# ### Question 3
#
# First, download the Olympic medal dataset (medals.csv). Use the following code to load the dataset.
#
# The columns give information on: <br>
# summer Olympic games--number of games and summer medals;  <br>
# winter Olympic games--number of games and winter medals;  <br>
# total Olympic games--number of games and total medals.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('medals.csv', index_col=0, skiprows=0)

# %% [markdown]
# 3. (1) Plot a histogram on the total number of gold medals in summer and the total number of gold medals in winter in the range between 0 and 100 (do not include 0).

# %%
# Your answer here
gold_sum = df[(df['Gold']>0) & (df['Gold']<=100)]
gold_win = df[(df['Gold.1']>0) & (df['Gold.1']<=100)]

plt.hist(gold_sum['Gold'], label='summer golds', bins=30, alpha=.7, edgecolor='red')
plt.hist(gold_win['Gold.1'], label='winter golds', bins=30, alpha=.7, edgecolor='red')
plt.legend()

plt.title('Total Number of Golds in Summer & Winter')
plt.xlabel('Range')
plt.ylabel('Number of Golds')
plt.show()



#plt.figure(1)
#plt.subplot(121)
#plt.hist(gold_sum['Gold'], bins=30, alpha=.7, color = 'red')
#plt.subplot(122)
#plt.hist(gold_win['Gold'], bins=30, alpha =.7 , color='yellow')
#plt.legend()
#plt.suptitle('')

# %% [markdown]
# 3. (2) For the top three countries with the largest number of combined medals (Combined Total), draw a line chart about the combined gold, silver, and bronze medals (Gold.2, Silver.2, Bronze.2). Use different styles for the line type, point type, color, and line width.

# %%
# Your answer here
top3 = df.copy()
top3 = top3.drop('Totals')
top3 = top3.sort_values('Combined total', ascending = False)[0:3]
top3 = top3.loc[:,'Gold.2':'Bronze.2']

y1 = top3.iloc[0,:]
y2 = top3.iloc[1,:]
y3 = top3.iloc[2,:]
x = range(3)
labels = ['Gold', 'Silver', 'Bronze']
plt.plot(x, y1, color='green', marker='o', linestyle='dashed',linewidth=1, label = 'United States')
plt.plot(x, y2, color='blue', marker='x', linestyle='--',linewidth=2, label ='Soviet Union')
plt.plot(x, y3, color='orange', marker='*', linestyle='-.', linewidth=3, label = 'Great Britain')
plt.xlabel('Medals')
plt.ylabel('Number of Medals')
plt.title('Top 3 Countries with The Largest Number of Combined Medals ')
plt.legend()
plt.xticks(x, labels, rotation = 'horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x7ff738709250>,
#   <matplotlib.axis.XTick at 0x7ff738709220>,
#   <matplotlib.axis.XTick at 0x7ff7386fcd60>],
#  [Text(0, 0, 'Gold'), Text(1, 0, 'Silver'), Text(2, 0, 'Bronze')])

# %% [markdown]
# 3. (3) For the top five countries with the largest number of combined medals (Combined Total), draw a stacked bar chart about the combined gold, silver, and bronze medals (Gold.2, Silver.2, Bronze.2).

# %%
# Your answer here
top5 = df.copy()
top5 = top5.drop('Totals')
top5 = top5.sort_values('Combined total', ascending = False)[0:5]
top5 = top5.loc[:,'Gold.2':'Bronze.2']
top5

y11 = top5.iloc[:,0]
y12 = top5.iloc[:,1]
y13 = top5.iloc[:,2]
x = range(5)
labels1 = ['United States', 'Soviet Union', 'Great Britain', 'Germany', 'France']

plt.bar(x, y11, color='r', label = 'Gold')
plt.bar(x, y12, bottom=y11, color='b', label = 'Silver')
plt.bar(x, y13, bottom=y11+y12, color='y', label = 'Bronze')
plt.legend()
plt.xticks(x, labels1, rotation = 'horizontal')
plt.xlabel('Countries')
plt.ylabel('Number of Medals')
plt.title('Top Five Countries with The Largest Number of Combined Medals')
# Out:
# Text(0.5, 1.0, 'Top Five Countries with The Largest Number of Combined Medals')
